# %%
import run_info_utils

# %%
df = run_info_utils.get_df_run_info()

# %%
df.head()
# Out:
#    all_correct_stop  batch_size  dev_set_size experiment_name  \
# 0              True          32            77            test
# 1              True          32           136  test_h1_record
# 2              True          32           256  test_h1_record
# 3              True          32           240  test_h1_record
# 4              True          32           240  test_h1_record
#
#   hidden_activation hidden_dimensions  init_all_correct_carry-0_epoch  \
# 0           sigmoid              [64]                             NaN
# 1           sigmoid              [64]                          1887.0
# 2           sigmoid              [64]                           764.0
# 3           sigmoid              [64]                          2381.0
# 4           sigmoid              [64]                          5025.0
#
#    init_all_correct_carry-12_epoch  init_all_correct_carry-1_epoch  \
# 0                              NaN                             NaN
# ...

# %%
run_info_utils.run_info_to_files()
# Out:
# The dataframe has saved as run_info/df_run_info.xlsx.
# The dataframe has saved as run_info/df_run_info.csv.
